# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilo1417/Danilo/blob/main/C%C3%B3pia_de_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materias = ['matática', 'História', 'Biologia']
notas = (8.5, 7.0, 9.2)
aluno = {'nome': 'Carlos', 'idade': 21, 'curso': 'engenharia'}

print('Matérias:', materias)
print('Notas:', notas)
print('Informações do aluno:', aluno)
# Out:
# Matérias: ['matática', 'História', 'Biologia']
# Notas: (8.5, 7.0, 9.2)
# Informações do aluno: {'nome': 'Carlos', 'idade': 21, 'curso': 'engenharia'}

# %% [markdown]
# Lista de acessorios

# %% [markdown]
# Carro!!!

# %%
acessorios = ['volante', 'banco', 'retrovisor']
especificacoes = (1000), (50), 'Litros'
carro = {'marca': 'fiat', 'modelo': 'quatro portas','ano': 2001 }
print('Acessórios:', acessorios)
print('Especificações:', especificacoes)
print('Informações do carro:', carro)
# Out:
# Acessórios: ['volante', 'banco', 'retrovisor']
# Especificações: (1000, 50, 'Litros')
# Informações do carro: {'marca': 'fiat', 'modelo': 'quatro portas', 'ano': 2001}
