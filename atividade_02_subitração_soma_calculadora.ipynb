# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilo1417/Danilo/blob/main/atividade_02_subitra%C3%A7%C3%A3o_soma_calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input ("Digite o seu nome: ")
print("O seu nome é: ", nome)
# Out:
# Digite o seu nome: 10
# O seu nome é:  10

# %%
#atividade 01
valor1 = int(input("Digite o seu valor: "))
valor2 = int(input("Digite o seu valor: "))
resultado = valor1 + valor2
print(resultado)
# Out:
# Digite o seu valor: 10
# Digite o seu valor: 10
# 20

# %%
#atividade 02
valor1 = int(input("Digite o seu valor: "))
valor2 = int(input("Digite o seu valor: "))
resultado = valor1 - valor2
print(resultado)
# Out:
# Digite o seu valor: 10
# Digite o seu valor: 20
# -10

# %%
#atividade 03
valor1 = int(input("Digite o seu valor: "))
valor2 = int(input("Digite o seu valor: "))
soma = valor1 + valor2
sub = valor1 - valor2
div = valor1 / valor2
mult = valor1 * valor2
print(soma, sub, div, mult)
# Out:
# Digite o seu valor: 10
# Digite o seu valor: 20
# 30 -10 0.5 200
